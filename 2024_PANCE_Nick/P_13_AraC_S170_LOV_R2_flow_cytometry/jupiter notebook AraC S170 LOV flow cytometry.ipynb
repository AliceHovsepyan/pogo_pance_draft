# %%
from cytoflow import *
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
op_0 = ImportOp(
    conditions={'CF_File': 'category'},
    tubes=[
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/01_sd2_AraC_WT_blue_light.fcs',
            conditions={'CF_File': '01_sd2_AraC_WT_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/02_sd2_AraC_R2_blue_light.fcs',
            conditions={'CF_File': '02_sd2_AraC_R2_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/03_sd2_AraC_S170_WT_LOV_1_blue_light.fcs',
            conditions={'CF_File': '03_sd2_AraC_S170_WT_LOV_1_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/04_sd2_AraC_S170_R2_LOV_1_blue_light.fcs',
            conditions={'CF_File': '04_sd2_AraC_S170_R2_LOV_1_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/05_AraC_S170_LOV_SwR1_R2_1_C3_blue_light.fcs',
            conditions={'CF_File':
                        '05_AraC_S170_LOV_SwR1_R2_1_C3_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/06_AraC_S170_LOV_SwR2_R2_1_C3_blue_light.fcs',
            conditions={'CF_File':
                        '06_AraC_S170_LOV_SwR2_R2_1_C3_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/07_sd2_AraC_WT_Arabinose_blue_light.fcs',
            conditions={'CF_File': '07_sd2_AraC_WT_Arabinose_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/08_sd2_AraC_R2_Arabinose_blue_light.fcs',
            conditions={'CF_File': '08_sd2_AraC_R2_Arabinose_blue_light'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/09_sd2_AraC _S170_WT_LOV_1_Arabinose_blue_light.fcs',
            conditions={
                'CF_File': '09_sd2_AraC _S170_WT_LOV_1_Arabinose_blue_light'
            }),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/10_sd2_AraC_S170_R2_LOV_1_Arabinose_blue_light.fcs',
            conditions={
                'CF_File': '10_sd2_AraC_S170_R2_LOV_1_Arabinose_blue_light'
            }),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/11_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_blue_light.fcs',
            conditions={
                'CF_File': '11_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_blue_light'
            }),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/12_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_blue_light.fcs',
            conditions={
                'CF_File': '12_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_blue_light'
            }),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/13_sd2_AraC_WT_dark.fcs',
            conditions={'CF_File': '13_sd2_AraC_WT_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/14_sd2_AraC_R2_dark.fcs',
            conditions={'CF_File': '14_sd2_AraC_R2_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/15_sd2_AraC_S170_WT_LOV_1_dark.fcs',
            conditions={'CF_File': '15_sd2_AraC_S170_WT_LOV_1_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/16_sd2_AraC_S170_R2_LOV_1_dark.fcs',
            conditions={'CF_File': '16_sd2_AraC_S170_R2_LOV_1_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/17_AraC_S170_LOV_SwR1_R2_1_C3_dark.fcs',
            conditions={'CF_File': '17_AraC_S170_LOV_SwR1_R2_1_C3_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/18_AraC_S170_LOV_SwR2_R2_1_C3_dark.fcs',
            conditions={'CF_File': '18_AraC_S170_LOV_SwR2_R2_1_C3_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/19_sd2_AraC_WT_Arabinose_dark.fcs',
            conditions={'CF_File': '19_sd2_AraC_WT_Arabinose_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/20_sd2_AraC_R2_Arabinose_dark.fcs',
            conditions={'CF_File': '20_sd2_AraC_R2_Arabinose_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/21_sd2_AraC_S170_WT_LOV_1_Arabinose_dark.fcs',
            conditions={'CF_File':
                        '21_sd2_AraC_S170_WT_LOV_1_Arabinose_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/22_sd2_AraC_S170_R2_LOV_1_Arabinose_dark.fcs',
            conditions={'CF_File':
                        '22_sd2_AraC_S170_R2_LOV_1_Arabinose_dark'}),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/23_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_dark.fcs',
            conditions={
                'CF_File': '23_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_dark'
            }),
        Tube(
            file=
            'C:/Users/lulug/OneDrive/Documents/master studium/Internship/Niopek lab/data/flourescence measurement/AraC_S170_LOV-Lulu/24_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_dark.fcs',
            conditions={
                'CF_File': '24_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_dark'
            })
    ],
    channels={
        'B525-A': 'B525_A',
        'B525-H': 'B525_H',
        'B690-A': 'B690_A',
        'B690-H': 'B690_H',
        'FSC-A': 'FSC_A',
        'FSC-H': 'FSC_H',
        'FSC-Width': 'FSC_Width',
        'R660-A': 'R660_A',
        'R660-H': 'R660_H',
        'R712-A': 'R712_A',
        'R712-H': 'R712_H',
        'R780-A': 'R780_A',
        'R780-H': 'R780_H',
        'SSC-A': 'SSC_A',
        'SSC-H': 'SSC_H',
        'Time': 'Time',
        'V450-A': 'V450_A',
        'V450-H': 'V450_H',
        'V525-A': 'V525_A',
        'V525-H': 'V525_H',
        'V610-A': 'V610_A',
        'V610-H': 'V610_H',
        'V660-A': 'V660_A',
        'V660-H': 'V660_H',
        'Y585-A': 'Y585_A',
        'Y585-H': 'Y585_H',
        'Y610-A': 'Y610_A',
        'Y610-H': 'Y610_H',
        'Y690-A': 'Y690_A',
        'Y690-H': 'Y690_H',
        'Y780-A': 'Y780_A',
        'Y780-H': 'Y780_H'
    })

ex_0 = op_0.apply()

# %%
op_1 = PolygonOp(name='E_coli', 
                 xchannel='FSC_A',
                 ychannel='SSC_A',
                 vertices=[(10349.355901892164, 15469.303942713834),
                           (10349.355901892164, 15469.303942713834),
                           (392.1641894714989, 2634.4366272415746),
                           (1554.6503716520342, 846.4595998377657),
                           (6255.030275947625, 1266.399252383683),
                           (18168.73733380093, 12570.066965287566)],
                 xscale='log',
                 yscale='log')

ex_1 = op_1.apply(ex_0)

# %%
op_1.default_view(subset='(CF_File == "01_sd2_AraC_WT_blue_light")',
                  huefacet='CF_File').plot(ex_0,
                                           xlim=(10.0, None),
                                           ylim=(10.0, None))

# %%
op_2 = PolygonOp(name='singlets',
                 xchannel='SSC_A',
                 ychannel='SSC_H',
                 vertices=[(700.8347190295943, 1464.1679336663285),
                           (700.8347190295943, 1464.1679336663285),
                           (700.8347190295943, 1464.1679336663285),
                           (1021.4537905227468, 924.1045986293287),
                           (20475.138847954488, 11013.945296358223),
                           (14496.305488910966, 14968.883958299772)],
                 xscale='log',
                 yscale='log')

ex_2 = op_2.apply(ex_1)

# %%
op_2.default_view(
    subset=
    '(CF_File == "01_sd2_AraC_WT_blue_light" or CF_File == "02_sd2_AraC_R2_blue_light" or CF_File == "13_sd2_AraC_WT_dark" or CF_File == "22_sd2_AraC_S170_R2_LOV_1_Arabinose_dark" or CF_File == "23_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_dark" or CF_File == "09_sd2_AraC _S170_WT_LOV_1_Arabinose_blue_light") and (E_coli == True)'
).plot(ex_1, xlim=(10.0, None), ylim=(10.0, None))

# %%
plot_obj = Kde1DView(
    channel='Y610_A',
    scale='log',
    subset=(
        '(CF_File == "06_AraC_S170_LOV_SwR2_R2_1_C3_blue_light" or CF_File == "12_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_blue_light" or '
        'CF_File == "18_AraC_S170_LOV_SwR2_R2_1_C3_dark" or CF_File == "24_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_dark") and '
        '(E_coli == True) and (singlets == True)'
    ),
    huefacet='CF_File'
)

# Plot the KDE with x and y labels
plot_obj.plot(ex_2, xlabel='mRFP flourescence', ylabel='Density')

fig = plt.gcf()  # Get the current figure
fig.set_size_inches(10, 8)  # Set width and height in inches

# Add a custom title
plt.title('AraC S170 LOV SwR2 R2 1 C3', fontsize = 22)

# Get the current handles and labels from the plot's legend
handles, labels = plt.gca().get_legend_handles_labels()

# Define new legend labels (replace this with your desired labels)
new_labels = ['blue light', 'blue light + Arabinose', 'dark', 'dark + Arabinose']  # Example

# Update the legend with the new labels
plt.legend(handles, new_labels, title='Conditions', loc='upper left', fontsize = 12, title_fontsize = 14)

# Show the plot
plt.show()

# %%
plot_obj1 = Kde1DView(
    channel='Y610_A',
    scale='log',
    subset=(
        '(CF_File == "01_sd2_AraC_WT_blue_light" or CF_File == "07_sd2_AraC_WT_Arabinose_blue_light" or '
        'CF_File == "13_sd2_AraC_WT_dark" or CF_File == "19_sd2_AraC_WT_Arabinose_dark") and '
        '(E_coli == True) and (singlets == True)'
    ),
    huefacet='CF_File'
)

# Plot the KDE with x and y labels
plot_obj1.plot(ex_2, xlabel='mRFP flourescence', ylabel='Density')

fig = plt.gcf()  # Get the current figure
fig.set_size_inches(10, 8)  # Set width and height in inches

# Add a custom title
plt.title('sd2 AraC WT', fontsize = 22)

# Get the current handles and labels from the plot's legend
handles, labels = plt.gca().get_legend_handles_labels()

# Define new legend labels (replace this with your desired labels)
new_labels = ['blue light', 'blue light + 16 mM Arabinose', 'dark', 'dark + 16 mM Arabinose']  # Example

# Update the legend with the new labels
plt.legend(handles, new_labels, title='Conditions', loc='upper left', fontsize = 12, title_fontsize = 14)

# Show the plot
plt.show()

# %%
# Define specific groups of CF files manually, with group titles
cf_groups = [
    {
        "group_title": "sd2 AraC WT",  # Group 1 Title
        "cf_files": [
            ("01_sd2_AraC_WT_blue_light", "Blue Light - No Arabinose"),
            ("07_sd2_AraC_WT_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("13_sd2_AraC_WT_dark", "Dark - No Arabinose"),
            ("19_sd2_AraC_WT_Arabinose_dark", "Dark - With Arabinose")
        ]
    },
    {
        "group_title": "sd2 AraC R2",  # Group 2 Title
        "cf_files": [
            ("02_sd2_AraC_R2_blue_light", "Blue Light - No Arabinose"),
            ("08_sd2_AraC_R2_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("14_sd2_AraC_R2_dark", "Dark - No Arabinose"),
            ("20_sd2_AraC_R2_Arabinose_dark", "Dark - With Arabinose")
        ]
    },
    {
        "group_title": "sd2 AraC S170 WT LOV 1",  # Group 3 Title
        "cf_files": [
            ("03_sd2_AraC_S170_WT_LOV_1_blue_light", "Blue Light - No Arabinose"),
            ("09_sd2_AraC _S170_WT_LOV_1_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("15_sd2_AraC_S170_WT_LOV_1_dark", "Dark - No Arabinose"),
            ("21_sd2_AraC_S170_WT_LOV_1_Arabinose_dark", "Dark - With Arabinose")
        ]
    },
    {
        "group_title": "sd2 AraC S170 R2 LOV 1",  # Group 4 Title
        "cf_files": [
            ("04_sd2_AraC_S170_R2_LOV_1_blue_light", "Blue Light - No Arabinose"),
            ("10_sd2_AraC_S170_R2_LOV_1_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("16_sd2_AraC_S170_R2_LOV_1_dark", "Dark - No Arabinose"),
            ("22_sd2_AraC_S170_R2_LOV_1_Arabinose_dark", "Dark - With Arabinose")
        ]
    },
    {
        "group_title": "AraC S170 LOV SwR1 R2 1 C3",  # Group 5 Title
        "cf_files": [
            ("05_AraC_S170_LOV_SwR1_R2_1_C3_blue_light", "Blue Light - No Arabinose"),
            ("11_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("17_AraC_S170_LOV_SwR1_R2_1_C3_dark", "Dark - No Arabinose"),
            ("23_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_dark", "Dark - With Arabinose")
        ]
    },
    {
        "group_title": "AraC S170 LOV SwR2 R2 1 C3",  # Group 6 Title
        "cf_files": [
            ("06_AraC_S170_LOV_SwR2_R2_1_C3_blue_light", "Blue Light - No Arabinose"),
            ("12_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_blue_light", "Blue Light - With Arabinose"),
            ("18_AraC_S170_LOV_SwR2_R2_1_C3_dark", "Dark - No Arabinose"),
            ("24_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_dark", "Dark - With Arabinose")
        ]
    }
]

# Loop through each predefined group of CF files to generate plots
for group in cf_groups:
    group_title = group["group_title"]  # Get the group title
    cf_files = group["cf_files"]  # Get the CF files and labels

    # Create a subset for the current group
    cf_conditions = " or ".join([f'(CF_File == "{cf_file}")' for cf_file, _ in cf_files])
    subset = f'({cf_conditions}) and (E_coli == True) and (singlets == True)'

    # Create the plot object
    plot_obj = Kde1DView(
        channel='Y610_A',
        scale='log',
        subset=subset,
        huefacet='CF_File'
    )

    # Plot the KDE
    plot_obj.plot(ex_2, xlabel='mRFP fluorescence', ylabel='Density')

    # Customize figure size
    fig = plt.gcf()
    fig.set_size_inches(12, 10)
    
    handles, labels = plt.gca().get_legend_handles_labels()
    new_labels = [title for _, title in cf_files]
    plt.legend(handles, new_labels, title='Conditions', loc='upper left', fontsize=12, title_fontsize=14)

    # Add a title for the group
    plt.title(group_title, fontsize=18)  # Use the group ti

# %%
import seaborn as sns

# Define specific groups of CF files manually, with group titles
cf_groups = [
    {
        "group_title": "AraC WT",  # Group 1 Title
        "cf_files": [
            ("01_sd2_AraC_WT_blue_light", "Blue Light"),
            ("13_sd2_AraC_WT_dark", "Dark"),
            ("07_sd2_AraC_WT_Arabinose_blue_light", "Blue Light"),
            ("19_sd2_AraC_WT_Arabinose_dark", "Dark")
        ]
    },
    {
        "group_title": "AraC R2",  # Group 2 Title
        "cf_files": [
            ("02_sd2_AraC_R2_blue_light", "Blue Light"),
            ("14_sd2_AraC_R2_dark", "Dark"),
            ("08_sd2_AraC_R2_Arabinose_blue_light", "Blue Light"),
            ("20_sd2_AraC_R2_Arabinose_dark", "Dark")
        ]
    },
    {
         "group_title": "AraC S170 WT LOV 1",  # Group 3 Title
        "cf_files": [
            ("03_sd2_AraC_S170_WT_LOV_1_blue_light", "Blue Light"),
            ("09_sd2_AraC _S170_WT_LOV_1_Arabinose_blue_light", "Blue Light"),
            ("15_sd2_AraC_S170_WT_LOV_1_dark", "Dark"),
            ("21_sd2_AraC_S170_WT_LOV_1_Arabinose_dark", "Dark")
        ]
    },
    {
        "group_title": "AraC S170 R2 LOV 1",  # Group 4 Title
        "cf_files": [
            ("04_sd2_AraC_S170_R2_LOV_1_blue_light", "Blue Light"),
            ("16_sd2_AraC_S170_R2_LOV_1_dark", "Dark"),
            ("10_sd2_AraC_S170_R2_LOV_1_Arabinose_blue_light", "Blue Light"),
            ("22_sd2_AraC_S170_R2_LOV_1_Arabinose_dark", "Dark")
        ]
    },
    {
        "group_title": "AraC S170 LOV R2 1.1.3",  # Group 5 Title
        "cf_files": [
            ("05_AraC_S170_LOV_SwR1_R2_1_C3_blue_light", "Blue Light"),
            ("17_AraC_S170_LOV_SwR1_R2_1_C3_dark", "Dark"),
            ("11_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_blue_light", "Blue Light"),
            ("23_AraC_S170_LOV_SwR1_R2_1_C3_Arabinose_dark", "Dark")
        ]
    },
    {
        "group_title": "AraC S170 LOV R2 2.1.3",  # Group 6 Title
        "cf_files": [
            ("06_AraC_S170_LOV_SwR2_R2_1_C3_blue_light", "Blue Light"),
            ("18_AraC_S170_LOV_SwR2_R2_1_C3_dark", "Dark"),
            ("12_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_blue_light", "Blue Light"),
            ("24_AraC_S170_LOV_SwR2_R2_1_C3_Arabinose_dark", "Dark")
        ]
    }
]

# Loop through each predefined group of CF files to generate separate plots
for group in cf_groups:
    group_title = group["group_title"]  # Get the group title
    cf_files = group["cf_files"]  # Get the CF files and labels

    # Generate two separate plots: one for Arabinose and one for Non-Arabinose
    for with_arabinose in [True, False]:
        subset_cf_files = filter_cf_files(cf_files, with_arabinose)
        
        if not subset_cf_files:
            continue  # Skip if there are no matching CF files

        # Create a subset for the current Arabinose/Non-Arabinose group
        cf_conditions = " or ".join([f'(CF_File == "{cf_file}")' for cf_file, _ in subset_cf_files])
        subset = f'({cf_conditions}) and (E_coli == True) and (singlets == True)'

        # Create the plot object
        plot_obj = Kde1DView(
            channel='Y610_A',
            scale='log',
            subset=subset,
            huefacet='CF_File'
        )

        # Define custom colors: blue for Blue Light and grey for Dark
        custom_colors = {
            "Blue Light": "#1f77b4",  # Blue
            "Dark": "#7f7f7f"         # Grey
        }

        # Set the palette manually
        sns.set_palette(sns.color_palette([custom_colors["Blue Light"], custom_colors["Dark"]]))

        # Plot the KDE
        plot_obj.plot(ex_2, xlabel='mRFP fluorescence', ylabel='Density')

        # Define axis limits
        x_limits = [0.1, 10000000]  
        y_limits = [0,2.5] 

        # Set consistent axis limits
        plt.xlim(x_limits)
        plt.ylim(y_limits)

        # Customize figure size
        fig = plt.gcf()
        fig.set_size_inches(12, 10)

        # Add a title for the group and condition
        condition_label = "With Arabinose" if with_arabinose else "Without Arabinose"
        plt.title(f"{group_title} - {condition_label}", fontsize=18)

        # Simplify and reorder the legend
        handles, labels = plt.gca().get_legend_handles_labels()
        new_order = [1, 0]  # Indexes for "Dark" and "Blue Light" in the current legend
        handles = [handles[i] for i in new_order]
        labels = ["Dark", "Blue Light"]
        plt.legend(handles, labels, title='Light Condition', loc='upper left', fontsize=12, title_fontsize=14)

        # Show the plot
        plt.show()
